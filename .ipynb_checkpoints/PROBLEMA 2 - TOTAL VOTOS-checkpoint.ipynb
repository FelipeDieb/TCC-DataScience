# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import itertools
from time import time
from random import *
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import  r2_score, mean_absolute_error,mean_squared_error
from sklearn.linear_model import LinearRegression
import pickle
from sklearn.model_selection import train_test_split

# %%
CAMINHO_DAS_BASES = 'C:/Users/felip/OneDrive/Documentos/tcc/HISTORICO_TCC2/BASES_DE_DADOS_FINALIZADAS/'

BASE_PREDICT_TOTAL_VOTOS_ML = pd.read_csv(CAMINHO_DAS_BASES+'BASE_PREDICT_TOTAL_VOTOS_ML_TRATADOS.txt',sep=';',encoding='ANSI')


TITULOS_X = ['ANO_ELEICAO', 'CODIGO_ESTADO', 'CODIGO_MUNICIPIO', 'NUMERO_PARTIDO',
       'ANALFABETO', 'ENSINO_FUNDAMENTAL_COMPLETO',
       'ENSINO_FUNDAMENTAL_INCOMPLETO', 'ENSINO_MEDIO_COMPLETO',
       'ENSINO_MEDIO_INCOMPLETO', 'LE_E_ESCREVE', 'SUPERIOR_COMPLETO',
       'SUPERIOR_INCOMPLETO', 'TOTAL_GASTO', 'SEXO', 'COD_GRAU_INSTRUCAO',
       'QTD_APTOS']


TITULO_Y = ['TOTAL_VOTOS']



X = BASE_PREDICT_TOTAL_VOTOS_ML[TITULOS_X]
y = BASE_PREDICT_TOTAL_VOTOS_ML[TITULO_Y]



X_Train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
#  # 1 ª FASE - RANDOM FOREST PARAMETROS

# %%
# TESTES N_ESTIMADORES

def criar_objeto():
    results = {
            'R2_SCORE' : [],
            'MAE':[],
            'RMSE':[],
            'VALOR':[]
    }
    return results

def returnMetricas(results,y_predict,valor):
    
    MAE = mean_absolute_error(y_test,y_predict)
    RMSE = mean_squared_error(y_test,y_predict)
    R2 = r2_score(y_test,y_predict)
    
    results['R2_SCORE'].append(R2)
    results['VALOR'].append(valor)
    results['MAE'].append(MAE)
    results['RMSE'].append(RMSE)
    return results,MAE
        
def test_n_estimators(lista,results):
    num_test = len(lista)
    for i in lista:
        robo = RandomForestRegressor(n_estimators=i)
        robo.fit(X_Train,y_train)
        y_predict = robo.predict(X_test)
        
        results,MAE =returnMetricas(results,y_predict,i)
        
        
        num_test = num_test-1
        print("--ESTIMADOR-- N_ESTIMATORS ","TESTE PARAM : ", i, " MAE : ",MAE," FALTAM ",num_test)
    DATA_FRAME = pd.DataFrame(results).sort_values('VALOR')
    DATA_FRAME.to_csv("C:/Users/felip/OneDrive/Documentos/tcc/HISTORICO_TCC2/RESULTADOS_PARAMETROS/RANDOM_FOREST/PROBL_2/N_ESTIMATORS_PARAM_2.txt",sep=";",encoding="ANSI",index_label=False)
    return DATA_FRAME

def test_max_depth(lista,results):
    num_test = len(lista)
    for i in lista:
        robo = RandomForestRegressor(max_depth=i)
        robo.fit(X_Train,y_train)
        y_predict = robo.predict(X_test)
        
        results,MAE =returnMetricas(results,y_predict,i)
        
        
        num_test = num_test-1
        print("--ESTIMADOR-- MAX_DEPTH_PARAM ","TESTE PARAM : ", i, " MAE : ",MAE," FALTAM ",num_test)
    DATA_FRAME = pd.DataFrame(results).sort_values('VALOR')
    DATA_FRAME.to_csv("C:/Users/felip/OneDrive/Documentos/tcc/HISTORICO_TCC2/RESULTADOS_PARAMETROS/RANDOM_FOREST/PROBL_2/MAX_DEPTH_PARAM_2.txt",sep=";",encoding="ANSI",index_label=False)
    return DATA_FRAME

def test_min_samples_split(lista,results):
    num_test = len(lista)
    for i in lista:
        robo = RandomForestRegressor(min_samples_split=i)
        robo.fit(X_Train,y_train)
        y_predict = robo.predict(X_test)
        
        results,MAE =returnMetricas(results,y_predict,i)
        
        
        num_test = num_test-1
        print("--ESTIMADOR-- MIN_SAMPLES_SPLIT_PARAM ","TESTE PARAM : ", i, " MAE : ",MAE," FALTAM ",num_test)
    DATA_FRAME = pd.DataFrame(results).sort_values('VALOR')
    DATA_FRAME.to_csv("C:/Users/felip/OneDrive/Documentos/tcc/HISTORICO_TCC2/RESULTADOS_PARAMETROS/RANDOM_FOREST/PROBL_2/MIN_SAMPLES_SPLIT_PARAM_2.txt",sep=";",encoding="ANSI",index_label=False)
    return DATA_FRAME

def test_min_samples_leafh(lista,results):
    num_test = len(lista)
    for i in lista:
        robo = RandomForestRegressor(min_samples_leaf=i)
        robo.fit(X_Train,y_train)
        y_predict = robo.predict(X_test)
        
        results,MAE =returnMetricas(results,y_predict,i)
        
        
        num_test = num_test-1
        print("--ESTIMADOR-- MIN_SAMPLES_LEAFTH_PARAM ","TESTE PARAM : ", i, " MAE : ",MAE," FALTAM ",num_test)
        
    DATA_FRAME = pd.DataFrame(results).sort_values('VALOR')
    DATA_FRAME.to_csv("C:/Users/felip/OneDrive/Documentos/tcc/HISTORICO_TCC2/RESULTADOS_PARAMETROS/RANDOM_FOREST/PROBL_2/MIN_SAMPLES_LEAFTH_PARAM_2.txt",sep=";",encoding="ANSI",index_label=False)
    return DATA_FRAME

def test_max_features(lista,results):
    num_test = len(lista)
    for i in lista:
        robo = RandomForestRegressor(max_features=i)
        robo.fit(X_Train,y_train)
        y_predict = robo.predict(X_test)
        
        results,MAE =returnMetricas(results,y_predict,i)
        
        
        num_test = num_test-1
        print("--ESTIMADOR-- MAX_FEATURES_PARAM ","TESTE PARAM : ", i, " MAE : ",MAE," FALTAM ",num_test)
    DATA_FRAME = pd.DataFrame(results).sort_values('VALOR')
    DATA_FRAME.to_csv("C:/Users/felip/OneDrive/Documentos/tcc/HISTORICO_TCC2/RESULTADOS_PARAMETROS/RANDOM_FOREST/PROBL_2/MAX_FEATURES_PARAM_2.txt",sep=";",encoding="ANSI",index_label=False)
    return DATA_FRAME

def start_test_random():
    print("Iniciando testes N_estimators : ")
    test_n_estimators([x for x in range(2,600,25)],criar_objeto())
    print("Iniciando testes max depth : ")
    test_max_depth([x for x in range(2,150,2)],criar_objeto())
    print("Iniciando testes split : ")
    test_min_samples_split([x for x in range(2,200,2)],criar_objeto())
    print("Iniciando testes leaf : ")
    test_min_samples_leafh([x for x in range(2,200,1)],criar_objeto())
    print("Iniciando testes features : ")
    test_max_features(['auto','sqrt','log2',None],criar_objeto())
    print("FINALIZADO , TESTADO E SALVO TODOS OS TESTES, PODE COMEMORAR !!! ")
    
start_test_random()
# Out:
# Iniciando testes N_estimators :
# C:\Users\felip\Anaconda3\lib\site-packages\ipykernel_launcher.py:28: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# --ESTIMADOR-- N_ESTIMATORS  TESTE PARAM :  2  MAE :  5248.678744938127  FALTAM  23
# C:\Users\felip\Anaconda3\lib\site-packages\ipykernel_launcher.py:28: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# --ESTIMADOR-- N_ESTIMATORS  TESTE PARAM :  27  MAE :  4305.252628065527  FALTAM  22
# C:\Users\felip\Anaconda3\lib\site-packages\ipykernel_launcher.py:28: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# --ESTIMADOR-- N_ESTIMATORS  TESTE PARAM :  52  MAE :  4381.243012403581  FALTAM  21
# ...

# %%
CAMINHO_DAS_BASES_RESULTS = 'C:/Users/felip/OneDrive/Documentos/tcc/HISTORICO_TCC2/RESULTADOS_PARAMETROS/RANDOM_FOREST/PROBL_2/'


MAX_FEATURES_PARAM_FL = pd.read_csv(CAMINHO_DAS_BASES_RESULTS+'/MAX_FEATURES_PARAM_2.txt',sep=';',encoding='ANSI')


MIN_SAMPLES_LEAFTH_PARAM_FL = pd.read_csv(CAMINHO_DAS_BASES_RESULTS+"MIN_SAMPLES_LEAFTH_PARAM_2.txt",sep=';',encoding='ANSI')

MIN_SAMPLES_SPLIT_PARAM_FL = pd.read_csv(CAMINHO_DAS_BASES_RESULTS+"MIN_SAMPLES_SPLIT_PARAM_2.txt",sep=';',encoding='ANSI')

MAX_DEPTH_PARAM_FL = pd.read_csv(CAMINHO_DAS_BASES_RESULTS+"MAX_DEPTH_PARAM_2.txt",sep=';',encoding='ANSI')


N_ESTIMATORS_PARAM_FL = pd.read_csv(CAMINHO_DAS_BASES_RESULTS+"N_ESTIMATORS_PARAM_2.txt",sep=';',encoding='ANSI')



def gerarGraficoEvolucao(BASE_PARAM,BASE_PARAM_2,TITLE,X):
    fig, ax = plt.subplots(figsize=(22,10))
    plt.title(TITLE,fontsize=20)
    plt.xlabel(X,fontsize=20)
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
    plt.ylabel("ERROR MAE",fontsize=20)
    line3, = ax.plot(list(BASE_PARAM.VALOR), list(BASE_PARAM.MAE), label='ERRO MAE FL')
    line4, = ax.plot(list(BASE_PARAM_2.VALOR), list(BASE_PARAM_2.MAE), label='ERROR MAE AD')
    ax.legend(prop={'size':35})
    plt.show()
    
def gerarGraficoEvolucaoR2(BASE_PARAM,BASE_PARAM_2,TITLE,X):
    fig, ax = plt.subplots(figsize=(22,10))
    plt.title(TITLE,fontsize=20)
    plt.xlabel(X,fontsize=20)
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
    plt.ylabel("R2 SCORE",fontsize=20)
    line3, = ax.plot(list(BASE_PARAM.VALOR), list(BASE_PARAM.R2_SCORE), label='R2 SCORE FA')
    line4, = ax.plot(list(BASE_PARAM_2.VALOR), list(BASE_PARAM_2.R2_SCORE), label='R2 SCORE AD')
    ax.legend(prop={'size':35})
    plt.show()
    
def gerarGraficoEvolucao_2(BASE_PARAM,TITLE,X):
    fig, ax = plt.subplots(figsize=(22,10))
    plt.title(TITLE,fontsize=20)
    plt.xlabel(X,fontsize=20)
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
    plt.ylabel("ERRO MAE",fontsize=20)
    line3, = ax.plot(list(BASE_PARAM.VALOR), list(BASE_PARAM.MAE), label='ERRO MAE FA')
    ax.legend(prop={'size':35})
    plt.show()
    
def gerarGraficoEvolucao_3(BASE_PARAM,TITLE,X):
    fig, ax = plt.subplots(figsize=(22,10))
    plt.title(TITLE,fontsize=20)
    plt.xlabel(X,fontsize=20)
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20)
    plt.ylabel("R2 SCORE",fontsize=20)
    line3, = ax.plot(list(BASE_PARAM.VALOR), list(BASE_PARAM.R2_SCORE), label='R2 SCORE FA')
    ax.legend(prop={'size':35})
    plt.show()
    
def ANALISE_DOS_TESTES_HIPERPARAMETRICOS_ERRO(BASE_SAMPLES_LEAF,BASE_SAMPLES_SPLIT,BASE_MAX_DEPTH,BASE_N_ESTIMATORS):
    plt.figure(1)
    fig, ax = plt.subplots(figsize=(20,10))
    plt.suptitle('VALORES DE ERRO PARA CADA HIPERPARÂMETRO')
    
    plt.subplot(221)
    plt.plot(list(BASE_SAMPLES_LEAF.VALOR), list(BASE_SAMPLES_LEAF.MAE), label='MEAN ABSOLUTE ERRO (MAE) FA')
    plt.title('HIPERPARÊMETRO SAMPLES LEAF - VALORES SEQUÊNCIAIS')
    plt.xlabel('VALORES APLICADOS',fontsize=10)
    plt.ylabel("VALORES DO ERRO (MAE)",fontsize=10)
    plt.grid(True)
    plt.legend()
    
    plt.subplot(222)
    plt.plot(list(BASE_SAMPLES_SPLIT.VALOR), list(BASE_SAMPLES_SPLIT.MAE), label='MEAN ABSOLUTE ERRO (MAE) (AC) FA')
    plt.title('HIPERPARÊMETRO SAMPLES SPLIT - VALORES SEQUÊNCIAIS')
    plt.xlabel('VALORES APLICADOS',fontsize=10)
    plt.ylabel("VALORES DO ERRO (MAE)",fontsize=10)
    plt.grid(True)
    plt.legend()

    plt.subplot(223)
    plt.plot(list(BASE_MAX_DEPTH.VALOR), list(BASE_MAX_DEPTH.MAE), label='MEAN ABSOLUTE ERRO (MAE) (AC) FA')
    plt.title('HIPERPARÊMETRO MAX DEPTH - VALORES SEQUÊNCIAIS')
    plt.xlabel('VALORES APLICADOS',fontsize=10)
    plt.ylabel("VALORES DO ERRO (MAE)",fontsize=10)
    plt.grid(True)
    plt.legend()

    plt.subplot(224)
    plt.plot(list(BASE_N_ESTIMATORS.VALOR), list(BASE_N_ESTIMATORS.MAE), label='MEAN ABSOLUTE ERRO (MAE) (AC) FA')
    plt.title('HIPERPARÊMETRO N ESTIMATORS - VALORES SEQUÊNCIAIS')
    plt.xlabel('VALORES APLICADOS',fontsize=10)
    plt.ylabel("VALORES DO ERRO (MAE)",fontsize=10)
    plt.grid(True)
    plt.legend()
    plt.show()
    
def ANALISE_DOS_TESTES_HIPERPARAMETRICOS_R2(BASE_SAMPLES_LEAF,BASE_SAMPLES_SPLIT,BASE_MAX_DEPTH,BASE_N_ESTIMATORS):
    plt.figure(1)
    fig, ax = plt.subplots(figsize=(20,10))
    plt.suptitle('VALORES DO R2 SCORE PARA CADA HIPERPARÂMETRO')
    
    plt.subplot(221)
    plt.plot(list(BASE_SAMPLES_LEAF.VALOR), list(BASE_SAMPLES_LEAF.R2_SCORE), label='R2_SCORE (R2) FA')
    plt.title('HIPERPARÊMETRO SAMPLES LEAF - VALORES SEQUÊNCIAIS')
    plt.xlabel('VALORES APLICADOS',fontsize=10)
    plt.ylabel("VALORES DO R2_SCORE",fontsize=10)
    plt.grid(True)
    plt.legend()
    
    plt.subplot(222)
    plt.plot(list(BASE_SAMPLES_SPLIT.VALOR), list(BASE_SAMPLES_SPLIT.R2_SCORE), label='R2_SCORE (R2) FA')
    plt.title('HIPERPARÊMETRO SAMPLES SPLIT - VALORES SEQUÊNCIAIS')
    plt.xlabel('VALORES APLICADOS',fontsize=10)
    plt.ylabel("VALORES DO R2_SCORE",fontsize=10)
    plt.grid(True)
    plt.legend()

    plt.subplot(223)
    plt.plot(list(BASE_MAX_DEPTH.VALOR), list(BASE_MAX_DEPTH.R2_SCORE), label='R2_SCORE (R2) FA')
    plt.title('HIPERPARÊMETRO MAX DEPTH - VALORES SEQUÊNCIAIS')
    plt.xlabel('VALORES APLICADOS',fontsize=10)
    plt.ylabel("VALORES DO R2_SCORE",fontsize=10)
    plt.grid(True)
    plt.legend()

    plt.subplot(224)
    plt.plot(list(BASE_N_ESTIMATORS.VALOR), list(BASE_N_ESTIMATORS.R2_SCORE), label='R2_SCORE (R2) FA')
    plt.title('HIPERPARÊMETRO N ESTIMATORS - VALORES SEQUÊNCIAIS')
    plt.xlabel('VALORES APLICADOS',fontsize=10)
    plt.ylabel("VALORES DO R2_SCORE",fontsize=10)
    plt.grid(True)
    plt.legend()
    plt.show()

# %%
ANALISE_DOS_TESTES_HIPERPARAMETRICOS_ERRO(MIN_SAMPLES_LEAFTH_PARAM_FL[0:50],MIN_SAMPLES_SPLIT_PARAM_FL[0:50],MAX_DEPTH_PARAM_FL[0:50],N_ESTIMATORS_PARAM_FL[0:50])

# %%
ANALISE_DOS_TESTES_HIPERPARAMETRICOS_R2(MIN_SAMPLES_LEAFTH_PARAM_FL[0:50],MIN_SAMPLES_SPLIT_PARAM_FL[0:50],MAX_DEPTH_PARAM_FL[0:50],N_ESTIMATORS_PARAM_FL[0:50])

# %%
gerarGraficoEvolucao_2(MAX_DEPTH_PARAM_FL,'EFEITO PRONFUNDIDADE DA ARVORE','TOTAL DE PROFUNDIDADE')
gerarGraficoEvolucao_3(MAX_DEPTH_PARAM_FL,'EFEITO PRONFUNDIDADE DA ARVORE','TOTAL DE PROFUNDIDADE')

# %%
MIN_SAMPLES_SPLIT_PARAM_FL.sort_values('VALOR')
# Out:
#             MAE  R2_SCORE          RMSE  VALOR
# 0   4442.818822  0.487963  1.313469e+09      2
# 1   4648.312208  0.371359  1.612578e+09      4
# 2   4383.878874  0.546930  1.162208e+09      6
# 3   4465.418790  0.512202  1.251290e+09      8
# 4   4500.406676  0.429201  1.464204e+09     10
# 5   4390.692161  0.503931  1.272506e+09     12
# 6   4529.158954  0.422475  1.481457e+09     14
# 7   4468.123716  0.471106  1.356708e+09     16
# 8   4585.971204  0.426681  1.470667e+09     18
# 9   4597.733925  0.405904  1.523964e+09     20
# 10  4515.931556  0.460699  1.383406e+09     22
# 11  4565.088760  0.441678  1.432197e+09     24
# 12  4570.045043  0.422972  1.480181e+09     26
# 13  4656.983541  0.367963  1.621288e+09     28
# 14  4621.075053  0.396194  1.548873e+09     30
# 15  4651.191715  0.410288  1.512718e+09     32
# 16  4591.397206  0.410704  1.511652e+09     34
# 17  4667.514690  0.392575  1.558156e+09     36
# 18  4624.633944  0.379400  1.591951e+09     38
# ...

# %%
gerarGraficoEvolucao_2(MIN_SAMPLES_SPLIT_PARAM_FL,'EFEITO MIN SAMPLES SPLIT','TOTAL DE NÓS PARA DIVISÃO')
gerarGraficoEvolucao_3(MIN_SAMPLES_SPLIT_PARAM_FL,'EFEITO MIN SAMPLES SPLIT','TOTAL DE NÓS PARA DIVISÃO')

# %%
MIN_SAMPLES_LEAFTH_PARAM_FL.sort_values('VALOR')
# Out:
#              MAE  R2_SCORE          RMSE  VALOR
# 0    4425.094928  0.459567  1.386310e+09      2
# 1    4348.735104  0.527131  1.212994e+09      3
# 2    4355.213520  0.458181  1.389865e+09      4
# 3    4551.545094  0.348628  1.670886e+09      5
# 4    4495.457913  0.443658  1.427119e+09      6
# 5    4386.722594  0.416886  1.495794e+09      7
# 6    4592.949551  0.405071  1.526101e+09      8
# 7    4475.813857  0.445548  1.422270e+09      9
# 8    4564.704059  0.425412  1.473922e+09     10
# 9    4655.506957  0.418354  1.492028e+09     11
# 10   4625.842481  0.432762  1.455069e+09     12
# 11   4593.355670  0.445516  1.422353e+09     13
# 12   4706.550929  0.429260  1.464052e+09     14
# 13   4662.754410  0.449045  1.413301e+09     15
# 14   4650.675456  0.404679  1.527107e+09     16
# 15   4775.185641  0.428279  1.466569e+09     17
# 16   4800.213324  0.426296  1.471654e+09     18
# 17   4735.250484  0.374124  1.605486e+09     19
# 18   4826.227240  0.410877  1.511207e+09     20
# ...

# %%
gerarGraficoEvolucao_2(MIN_SAMPLES_LEAFTH_PARAM_FL,'EFEITO MIN SAMPLES LEAFTH','TOTAL DE NÓS FOLHA')
gerarGraficoEvolucao_3(MIN_SAMPLES_LEAFTH_PARAM_FL,'EFEITO MIN SAMPLES LEAFTH','TOTAL DE NÓS FOLHA')

# %%
N_ESTIMATORS_PARAM_FL.sort_values('VALOR')
# Out:
#             MAE  R2_SCORE          RMSE  VALOR
# 0   5248.678745  0.184264  2.092511e+09      2
# 1   4305.252628  0.548575  1.157988e+09     27
# 2   4381.243012  0.491418  1.304605e+09     52
# 3   4375.228983  0.473078  1.351651e+09     77
# 4   4368.379061  0.483092  1.325963e+09    102
# 5   4372.732686  0.480177  1.333439e+09    127
# 6   4331.285900  0.484473  1.322422e+09    152
# 7   4317.633421  0.502080  1.277256e+09    177
# 8   4336.236855  0.504328  1.271489e+09    202
# 9   4328.219357  0.511848  1.252199e+09    227
# 10  4317.681186  0.495472  1.294206e+09    252
# 11  4291.058473  0.516593  1.240027e+09    277
# 12  4352.675849  0.500650  1.280923e+09    302
# 13  4337.907289  0.485891  1.318783e+09    327
# 14  4319.818935  0.507011  1.264605e+09    352
# 15  4317.356247  0.499534  1.283786e+09    377
# 16  4322.934223  0.495935  1.293019e+09    402
# 17  4301.147749  0.505063  1.269603e+09    427
# 18  4325.873537  0.495703  1.293613e+09    452
# ...

# %%
gerarGraficoEvolucao_2(N_ESTIMATORS_PARAM_FL,"EFEITO QUANTIDADE DE ÁRVORES","QUANTIDADE DE ÁRVORES")
gerarGraficoEvolucao_3(N_ESTIMATORS_PARAM_FL,"EFEITO QUANTIDADE DE ÁRVORES","QUANTIDADE DE ÁRVORES")

# %%
colunas = list(MAX_FEATURES_PARAM_FL.VALOR)
valores_acuracia = list(MAX_FEATURES_PARAM_FL.MAE) 
posicao = np.arange(len(colunas))

def plota_barra_max_features():
   fig, ax = plt.subplots(figsize=(22,10))
   plt.barh( posicao,valores_acuracia , align='center', color='blue')
   plt.yticks( posicao, colunas,fontsize=20)
   plt.xticks(fontsize=20)
   plt.xlabel('ERROR MAE',fontsize=20)
   plt.title('ERROR MAE VS MAX FEATURES',fontsize=30)
    
plota_barra_max_features()

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_dist_fl = {"max_depth": [x for x in range(17,35,3)],
              "min_samples_split": [x for x in range(6,15,2)],
              "min_samples_leaf":[x for x in range(2,10,2)],
               "n_estimators":[x for x in range(27,67,20)]}

# %%
grid_search_ad = GridSearchCV(RandomForestRegressor(), param_dist_fl,refit='neg_mean_absolute_error', verbose=3,scoring=['neg_mean_absolute_error', 'neg_mean_squared_error','r2'])

start = time()
grid_search_ad.fit(X_Train, y_train)
# Out:
# C:\Users\felip\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\felip\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:528: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# Fitting 3 folds for each of 240 candidates, totalling 720 fits
# [CV] max_depth=17, min_samples_leaf=2, min_samples_split=6, n_estimators=27
# ...

# %%
pickle.dump(grid_search_ad, open('C:/Users/felip/OneDrive/Documentos/tcc/HISTORICO_TCC2/RESULTADOS_PARAMETROS/MODELOS/GRID_FL_PROBL_2_SEM_VOTOS_3.sav', 'wb'))

# %%
grid_search_ad.best_score_
# Out:
# -4973.504701252632

# %%
X_Train
# Out:
#         ANO_ELEICAO  CODIGO_ESTADO  CODIGO_MUNICIPIO  NUMERO_PARTIDO  \
# 7633         2016.0           16.0           12149.0            13.0
# 12706        2016.0           14.0           21695.0            25.0
# 548          2008.0           13.0            4111.0            45.0
# 3124         2012.0            2.0           28452.0            45.0
# 2454         2012.0           20.0             655.0            23.0
# 31437        2012.0            5.0           38164.0            45.0
# 2533         2008.0            7.0           56499.0            25.0
# 4520         2016.0           17.0           74616.0            45.0
# 7626         2012.0           17.0           79391.0            11.0
# 14040        2016.0           13.0            4308.0            45.0
# 3631         2016.0           25.0           61360.0            13.0
# 37338        2008.0           10.0           45438.0            11.0
# 1413         2008.0           20.0             213.0            15.0
# ...

# %%
c

# %%
X_Train_padrao
# Out:
#        ANO_ELEICAO  CODIGO_ESTADO  CODIGO_MUNICIPIO  NUMERO_PARTIDO  \
# 38160     1.191788      -0.251350         -1.568695        2.293110
# 24885    -0.029584       0.306984          0.816322       -0.963070
# 5394     -1.250956      -0.670101         -0.045310       -0.963070
# 1839     -1.250956      -1.368019         -0.386266        0.544420
# 19724    -0.029584      -0.670101         -0.325585       -0.118875
# 1423     -1.250956      -1.368019         -0.459452       -0.963070
# 2338     -1.250956      -1.228435         -1.207615        2.293110
# 9218     -1.250956       0.306984          0.996897       -0.842471
# 25245    -0.029584       0.446567          0.266125       -1.023370
# 5266     -1.250956      -0.670101         -0.067724       -0.963070
# 21864    -0.029584      -0.390934          1.649561       -0.842471
# 8647     -1.250956       0.167400         -1.343020        0.785619
# 43653     1.191788       1.144485          1.013160       -0.721872
# ...

# %%
param_dist_rl = {"fit_intercept": [True,False],
              "normalize": [True,False]}

# %%
grid_search_rl = GridSearchCV(LinearRegression(), param_dist_rl,refit='neg_mean_absolute_error', verbose=3,scoring=['neg_mean_absolute_error', 'neg_mean_squared_error','r2'])

grid_search_rl.fit(X_Train_padrao, y_train_padrao)
# Out:
# C:\Users\felip\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# [CV] fit_intercept=True, normalize=True ..............................
# [CV]  fit_intercept=True, normalize=True, neg_mean_absolute_error=-5324.656144305594, neg_mean_squared_error=-554885240.5448989, r2=0.5981557173116641, total=   0.0s
# [CV] fit_intercept=True, normalize=True ..............................
# ...

# %%
r2_score(y_test_padrao,grid_search_rl.predict(X_test_padrao))
# Out:
# 0.7905978182483758

# %%
pickle.dump(grid_search_rl, open('C:/Users/felip/OneDrive/Documentos/tcc/HISTORICO_TCC2/RESULTADOS_PARAMETROS/MODELOS/GRID_RL_PROBL_2_SEM_VOTOS_3.sav', 'wb'))
